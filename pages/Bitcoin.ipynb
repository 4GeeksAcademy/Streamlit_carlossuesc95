# %%
import streamlit as st
import pandas as pd
import streamlit as st
import yfinance as yf

# %%
ticker=yf.Ticker("BTC-USD")
# Capitalización de mercado
cap=ticker.info['marketCap']
# Volumen 24h
volumen=ticker.info["volume24Hr"]

#Cargamos los datos
precios=ticker.history(period='5y')['Close']
#Ajustamos el indice
precios=precios.sort_index(ascending=False).reset_index()
# Precio actual
pr_actual=precios['Close'].iloc[0]
# Rentabilidad 1 mes (30 días)
r30=(precios['Close'].iloc[0]-precios['Close'].iloc[30])/precios['Close'].iloc[30]*100
# Rentabilidad 1 año (360 días)
r360=(precios['Close'].iloc[0]-precios['Close'].iloc[360])/precios['Close'].iloc[360]*100
# Rentabilidad 5 años (1800 días)
r1800=(precios['Close'].iloc[0]-precios['Close'].iloc[1800])/precios['Close'].iloc[1800]*100

#Mostramos los resultados
st.write(f'Precio actual {pr_actual}')
st.write(f'Capitalización de mercado {cap}')
st.write(f'Volumen 24h {volumen}')
st.write(f'Rentabilidad a 1 mes (30 días) {r30}')
st.write(f'Rentabilidad a 1 año (360 días) {r360}')
st.write(f'Rentabilidad a 5 años (1800 días) {r1800}')
# Out:
# 2026-01-10 11:36:36.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 11:36:36.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
ticker=yf.Ticker("BTC-USD")
precios=ticker.history(period='5y')['Close']
# obtenemos la fecha de inicio y finalizacion :
ticker.pd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 precios=ticker.history(period='5y')['Close']
#       3 # obtenemos la fecha de inicio y finalizacion :
# ----> 4 ticker['date']
#
# TypeError: 'Ticker' object is not subscriptable
