# %%
import streamlit as st
import pandas as pd
import streamlit as st
import yfinance as yf

# %%
ticker=yf.Ticker("ETH-USD")
# Capitalización de mercado
cap=ticker.info['marketCap']
# Volumen 24h
volumen=ticker.info["volume24Hr"]

#Cargamos los datos
precios=ticker.history(period='5y')['Close']
#Ajustamos el indice
precios=precios.sort_index(ascending=False).reset_index()
# Precio actual
pr_actual=precios['Close'].iloc[0]
# Rentabilidad 1 mes (30 días)
r30=(precios['Close'].iloc[0]-precios['Close'].iloc[30])/precios['Close'].iloc[30]*100
# Rentabilidad 1 año (360 días)
r360=(precios['Close'].iloc[0]-precios['Close'].iloc[360])/precios['Close'].iloc[360]*100
# Rentabilidad 5 años (1800 días)
r1800=(precios['Close'].iloc[0]-precios['Close'].iloc[1800])/precios['Close'].iloc[1800]*100

#Mostramos los resultados
st.write(f'Precio actual {pr_actual}')
st.write(f'Capitalización de mercado {cap}')
st.write(f'Volumen 24h {volumen}')
st.write(f'Rentabilidad a 1 mes (30 días) {r30}')
st.write(f'Rentabilidad a 1 año (360 días) {r360}')
st.write(f'Rentabilidad a 5 años (1800 días) {r1800}')
# Out:
# 2026-01-10 19:36:50.680 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.714
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-01-10 19:36:50.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-10 19:36:50.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
ticker.info
# Out:
# {'website': 'https://www.ethereum.org/',
#  'companyOfficers': [],
#  'blockNumber': 15537411,
#  'blockReward': 2.0,
#  'netHashesPerSecond': '587053830136465',
#  'twitter': 'https://twitter.com/ethereum',
#  'name': 'Ethereum',
#  'startDate': 1438905600,
#  'description': 'Ethereum (ETH) is a cryptocurrency . Ethereum has a current supply of 120,694,733.74028911. The last known price of Ethereum is 3,093.34537972 USD and is up 0.19 over the last 24 hours. It is currently trading on 11376 active market(s) with $14,175,883,350.38 traded over the last 24 hours. More information can be found at https://www.ethereum.org/.',
#  'executiveTeam': [],
#  'whitepaper': 'https://ethereum.org/en/whitepaper/',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 3083.5847,
#  'open': 3083.5847,
#  'dayLow': 3075.2556,
#  'dayHigh': 3098.1575,
#  'regularMarketPreviousClose': 3083.5847,
#  'regularMarketOpen': 3083.5847,
#  'regularMarketDayLow': 3075.2556,
#  'regularMarketDayHigh': 3098.1575,
#  'volume': 8110004736,
#  'regularMarketVolume': 8110004736,
#  'averageVolume': 30130845667,
#  'averageVolume10days': 19668636845,
#  'averageDailyVolume10Day': 19668636845,
#  'marketCap': 372622393344,
#  'fiftyTwoWeekLow': 1386.7993,
#  'fiftyTwoWeekHigh': 4953.733,
#  'allTimeHigh': 4953.733,
#  'allTimeLow': 82.82989,
#  'fiftyDayAverage': 3022.9998,
#  'twoHundredDayAverage': 3622.7937,
#  'currency': 'USD',
#  'fromCurrency': 'ETH',
#  'toCurrency': 'USD=X',
#  'lastMarket': 'CoinMarketCap',
#  'coinMarketCapLink': 'https://coinmarketcap.com/currencies/ethereum',
#  'volume24Hr': 8110004736,
#  'volumeAllCurrencies': 8110004736,
#  'circulatingSupply': 120694736,
#  'maxSupply': 0,
#  'totalSupply': 120694736,
#  'tradeable': False,
#  'fullyDilutedValue': 372622426070,
#  'volume24HrMarketCapPercent': 0.021764673,
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'ETH-USD',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Cryptocurrency',
#  'quoteSourceName': 'CoinMarketCap',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': 0.5644103,
#  'regularMarketPrice': 3087.313,
#  'regularMarketChange': 17.327148,
#  'regularMarketDayRange': '3075.2556 - 3098.1575',
#  'fullExchangeName': 'CCC',
#  'averageDailyVolume3Month': 30130845667,
#  'coinImageUrl': 'https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png',
#  'logoUrl': 'https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png',
#  'fiftyTwoWeekLowChange': 1700.5137,
#  'fiftyTwoWeekLowChangePercent': 1.2262146,
#  'fiftyTwoWeekRange': '1386.7993 - 4953.733',
#  'fiftyTwoWeekHighChange': -1866.4199,
#  'fiftyTwoWeekHighChangePercent': -0.3767704,
#  'fiftyTwoWeekChangePercent': -6.06817,
#  'shortName': 'Ethereum USD',
#  'longName': 'Ethereum USD',
#  'corporateActions': [],
#  'regularMarketTime': 1768073700,
#  'exchange': 'CCC',
#  'messageBoardId': 'finmb_ETH_CCC',
#  'exchangeTimezoneName': 'UTC',
#  'exchangeTimezoneShortName': 'UTC',
#  'gmtOffSetMilliseconds': 0,
#  'market': 'ccc_market',
#  'esgPopulated': False,
#  'fiftyDayAverageChange': 64.31323,
#  'fiftyDayAverageChangePercent': 0.021274641,
#  'twoHundredDayAverageChange': -535.4807,
#  'twoHundredDayAverageChangePercent': -0.14780878,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'cryptoTradeable': True,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1510185600000,
#  'trailingPegRatio': None}
